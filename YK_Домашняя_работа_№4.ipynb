# %% [markdown]
# <a href="https://colab.research.google.com/github/yauheniyakarabliova/Mathshub/blob/main/YK_%D0%94%D0%BE%D0%BC%D0%B0%D1%88%D0%BD%D1%8F%D1%8F_%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%B0_%E2%84%964.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Домашняя работа №4

# %% [markdown]
# ## Задача 1
#
# Напишите функцию, которая будет принимать произвольное число аргументов с данными о сотруднике и сохранять их в словарь. Функция должна возвращать словарь.
#
# В качестве данных о сотруднике могут передаваться имя, фамилия, занимаемая должность, опыт работы в годах, дата рождения. Функция должна учитывать, что могут быть введены не все данные о сотруднике - даже в этом случае данные должны быть записаны в словарь.

# %% [markdown]
# ## Задача 2
#
# Напишите функцию, которая будет возвращать количество различных элементов в списке. Список должен передаваться в качестве аргумента.

# %% [markdown]
# ## Задача 3
#
# Напишите функцию, которая будет переводить количество больших или маленьких ложек в граммы.
#
# Аргументы фукнции: количество ложек, вид ложки (большая, маленькая)
#
# В качестве стандарта возьмите количество грамм в одной большой ложке - 20 грамм, а в одной маленькой ложке - 5 грамм.
#
# Результат выполнения фукнции должен возвращать только число грамм.

# %% [markdown]
# ## Задача 4
#
# Напишите функцию, которая будет удалять все нечетные элементы из списка. Список должен быть передан в функцию в качестве аргумента.

# %% [markdown]
# ## Задача 5
#
# Напишите функцию, которая будет выполнять простые математические операции - сложение, вычитание, умножение и деление.
#
# Аргументы фукнции: два числа (не обязательно целые), знак математического операции.
#
# Функция должно вернуть только результат математической операции.

# %% [markdown]
# ## Задача 6
#
# Напишите функцию, которая будет приводить переданную строку к удобночитаемому виду. Для этого нужно сделать все большие буквы внутри текста - маленькими, а первую букву строки - заглавной.
#
# Аргумент функции - строка, которую необходимо преобразовать.
#
# Функция должна вернуть преобразованную строку.
#
#
# Например, строка `'привет, КаК дЕлА?'`
#
# После выполнения фукнции будет иметь вид: `'Привет, как дела?'`

# %% [markdown]
# ## Задача 7
#
# Напишите функцию, которая будет возвращать по введенному слову антоним этого слова. Для реализации механизма поиска антонимов необходимо создать словарь антонимов (не больше 10 примеров).
#
# Аргумент функции - строка, содержащая слово, для которого будем искать антоним.
#
# Если для указанного слова не существует антонима в словаре, необходимо вывести сообщение об этом.
#
# Функция возвращает строку - слово-антоним.
